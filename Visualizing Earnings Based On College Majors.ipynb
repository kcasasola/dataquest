# %%
### 1) Introduction

# %matplotlib inline 
import pandas as pd
recent_grads = pd.read_csv("recent-grads.csv") # read
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
print(recent_grads.head())
print(recent_grads.tail())
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
print(recent_grads.describe())
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads.shape[0]
recent_grads.dropna()
print(raw_data_count)
# Out:
# 173

# %%
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape[0]
cleaned_data_count
# Out:
# 172

# %%
## 2) Pandas, Scatter Plots
recent_grads.plot(x ='Sample_size',y = 'Median', kind = 'scatter')
recent_grads.plot(x ='Sample_size',y = 'Unemployment_rate', kind = 'scatter')
recent_grads.plot(x ='Full_time',y = 'Median', kind = 'scatter')
recent_grads.plot(x ='ShareWomen',y = 'Unemployment_rate', kind = 'scatter')
recent_grads.plot(x ='Men',y = 'Median', kind = 'scatter')
recent_grads.plot(x ='Women',y = 'Median', kind = 'scatter')

# %% [markdown]
# Do students in popular majors make more money? NO
# Do studnets that were majority female make moremoney NO
# LInkk betwene fultime emp

# %%
recent_grads['Sample_size'].hist(bins = 25, range = (0,5000)) # sample size

# %%
recent_grads['Median'].hist()

# %% [markdown]
# Median Salary is about 30 to 40K

# %%
recent_grads['Employed'].hist(bins = 20, range = (1,320000))

# %%
recent_grads['Full_time'].hist(bins= 20, range = (0,300000))

# %%
recent_grads['ShareWomen'].hist(bins = 20)

# %% [markdown]
# More than half are predominantly female majors. 60?

# %%
recent_grads['Men'].hist(bins= 20, range = (0,20000))

# %%
recent_grads['Women'].hist(bins= 20, range = (0,200000))

# %%
from pandas.tools.plotting import scatter_matrix 

scatter_matrix(recent_grads[['Women', 'Men']], figsize = (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9188d4c198>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9188c2edd8>]], dtype=object)

# %% [markdown]
# More variation in the employment numbers of men than women, sugesting there when there are a lot of men employed theres not as many women employed.

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9188c287f0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9188ad0e80>]], dtype=object)

# %% [markdown]
# Less people in the profession, more likely they will have variation in the median amount of money.

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median','Unemployment_rate']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f91889fa128>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f91887d7908>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Median','ShareWomen','Full_time','Unemployment_rate']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f918866b198>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f91882758d0>]], dtype=object)

# %%
### 5  Pandas, Bar Plot
recent_grads[:5]['Women'].plot(kind = 'bar')

# %%
recent_grads[:5].plot.bar(x='Major', y='Women')

# %%
recent_grads.sort_values('Median').head(10).plot.bar(x = "Major", y = "ShareWomen")

# %%
recent_grads.sort_values("Median", ascending = True).tail(10).plot.bar(x = 'Major',y = "ShareWomen" )

# %%
recent_grads.sort_values('Median').head(10).plot.bar(x = 'Major', y = 'Unemployment_rate')

# %%
recent_grads.sort_values('Median').tail(10).plot.bar(x = 'Major', y = 'Unemployment_rate')

# %% [markdown]
# Generally, those on the tail end of medians (making the most) have a lower unemployment than the ones who have a low median salary.

# %%
# Grouped Bar Plot to compare number men with number of women
recent_grads.sort_values('Median').head(10).plot.bar(x = 'Major', y = ['Men', 'Women'])

# %%
# Grouped Bar Plot to compare number men with number of women
recent_grads.sort_values('Median').tail(10).plot.bar(x = 'Major', y = ['Men', 'Women'])

# %%
recent_grads['Median'].boxplot()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-74-5895bbcd44d3> in <module>()
# ----> 1 recent_grads['Median'].boxplot()
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'boxplot'
